# %% [markdown]
# # Some other examples with pandas

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
mpl.rcParams['figure.dpi'] = 96

# %%
df = pd.read_csv('clementinum.csv')
df.head(10)
# Out:
#    year  month  day  avg  max  min  prec
# 0  1972      1    1  0.6  2.8 -0.3   0.0
# 1  1972      1    2  1.6  2.5 -1.4   0.0
# 2  1972      1    3  3.5  4.0  2.3   0.0
# 3  1972      1    4  4.0  4.8  2.9   0.2
# 4  1972      1    5  2.2  3.6  1.3   3.0
# 5  1972      1    6  0.5  2.3 -1.2   0.0
# 6  1972      1    7  1.7  2.3  0.8   0.6
# 7  1972      1    8  1.2  1.8  0.0   1.1
# 8  1972      1    9  1.7  2.2  0.2   0.0
# 9  1972      1   10  2.1  2.6  1.0   0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16071 entries, 0 to 16070
# Data columns (total 7 columns):
# year     16071 non-null int64
# month    16071 non-null int64
# day      16071 non-null int64
# avg      16071 non-null float64
# max      16071 non-null float64
# min      16071 non-null float64
# prec     16071 non-null float64
# dtypes: float64(4), int64(3)
# memory usage: 879.0 KB

# %%
df.groupby('year')['avg'].mean().plot();

# %%
df.groupby('year')['avg'].mean().plot()
df.groupby('year')['min'].mean().plot()
df.groupby('year')['max'].mean().plot();

# %%
fig, ax = subplots(figsize=(12,6))
sel = df[df.year<2000]
sel.boxplot(column='avg', by='year', ax=ax)
ax.axhline(df.avg.mean(), color='r');

# %%
fig, ax = subplots(figsize=(12,6))
sel = df[df.year>=2000]
sel.boxplot(column='avg', by='year', ax=ax)
ax.axhline(df.avg.mean(), color='r');

# %%
df.boxplot(column='avg', by='month');

# %%
df[df.year<2000].boxplot(column='avg', by='month');

# %%
df[df.year>=2000].boxplot(column='avg', by='month');

# %%
df[df.year<2000].groupby('month')['avg'].mean().plot(marker='o', label='Do roku 2000')
df[df.year>=2000].groupby('month')['avg'].mean().plot(marker='o', label='Od roku 2000')
legend();
