# %% [markdown]
# # Working with timeseries

# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv('neic_new.csv', parse_dates=['time'], index_col=0)
df.head(10)
# Out:
#                          latitude  longitude  depth  mag  \
# time
# 1973-01-01 11:42:37.500   -35.513    -16.211   33.0  6.0
# 1973-01-05 13:54:29.100   -38.997    175.232  150.0  6.2
# 1973-01-06 15:52:41.900   -14.665    166.384   36.0  6.1
# 1973-01-18 09:28:14.100    -6.868    149.993   43.0  6.8
# 1973-01-22 00:37:58.000    18.601   -104.967   33.0  6.1
# 1973-01-27 13:08:43.700    -0.115    123.931   55.0  6.0
# 1973-01-30 21:01:12.500    18.481   -102.996   43.0  7.5
# 1973-01-31 20:55:53.100    28.206    139.227  498.0  6.0
# 1973-02-01 05:14:20.600   -22.655    -66.195  229.0  6.1
# 1973-02-06 10:37:10.100    31.398    100.581   33.0  7.4
#
#                                                         place
# time
# 1973-01-01 11:42:37.500           southern Mid-Atlantic Ridge
# 1973-01-05 13:54:29.100           North Island of New Zealand
# 1973-01-06 15:52:41.900                               Vanuatu
# 1973-01-18 09:28:14.100  New Britain region, Papua New Guinea
# 1973-01-22 00:37:58.000              offshore Jalisco, Mexico
# 1973-01-27 13:08:43.700                   Sulawesi, Indonesia
# 1973-01-30 21:01:12.500                     Michoacan, Mexico
# 1973-01-31 20:55:53.100           Bonin Islands, Japan region
# 1973-02-01 05:14:20.600                      Jujuy, Argentina
# 1973-02-06 10:37:10.100                western Sichuan, China

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6017 entries, 1973-01-01 11:42:37.500000 to 2015-11-11 02:46:19.900000
# Data columns (total 5 columns):
# latitude     6017 non-null float64
# longitude    6017 non-null float64
# depth        6017 non-null float64
# mag          6017 non-null float64
# place        6016 non-null object
# dtypes: float64(4), object(1)
# memory usage: 282.0+ KB

# %%
df['year'] = df.index.year

# %%
df.head()
# Out:
#                          latitude  longitude  depth  mag  \
# time
# 1973-01-01 11:42:37.500   -35.513    -16.211   33.0  6.0
# 1973-01-05 13:54:29.100   -38.997    175.232  150.0  6.2
# 1973-01-06 15:52:41.900   -14.665    166.384   36.0  6.1
# 1973-01-18 09:28:14.100    -6.868    149.993   43.0  6.8
# 1973-01-22 00:37:58.000    18.601   -104.967   33.0  6.1
#
#                                                         place  year
# time
# 1973-01-01 11:42:37.500           southern Mid-Atlantic Ridge  1973
# 1973-01-05 13:54:29.100           North Island of New Zealand  1973
# 1973-01-06 15:52:41.900                               Vanuatu  1973
# 1973-01-18 09:28:14.100  New Britain region, Papua New Guinea  1973
# 1973-01-22 00:37:58.000              offshore Jalisco, Mexico  1973

# %%
df.groupby('year').size().plot()

# %%
df['month'] = df.index.month

# %%
df.groupby('month').size().plot()

# %%
df.groupby('month')['mag'].mean().plot()

# %%
fig, ax = subplots(figsize=(14,4))
df.boxplot(column='mag', by='year', rot=90, ax=ax);
